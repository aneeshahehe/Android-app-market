# %% [markdown]
# ## 1. Remove duplicate values

# %%
import pandas as pd

apps_dupes = pd.read_csv(r'C:\Users\KIIT\OneDrive\Desktop\DA project\googleplaystore.csv')
apps = apps_dupes.drop_duplicates(subset = 'App')

print('Total number of apps in our dataset:', apps['App'].value_counts().sum())

#show a sample of our dataset

n=10
apps.sample(n)
# Out:
# Total number of apps in our dataset: 9660
#                                         App             Category  Rating  \
# 8920               La citadelle du musulman  BOOKS_AND_REFERENCE     4.5
# 9064                        Differential Dx              MEDICAL     4.0
# 7822         Asiimov Skin - CS GO Icon Pack      PERSONALIZATION     4.6
# 1463                      Living Smart Home       HOUSE_AND_HOME     4.6
# 7033                            BZ Reminder             BUSINESS     4.7
# 9074                             DY Fitness   HEALTH_AND_FITNESS     NaN
# 1210                              9th stage       FOOD_AND_DRINK     4.5
# 8204                       DB Streckenagent  MAPS_AND_NAVIGATION     3.9
# 6870                          BV Taxi Sudan  MAPS_AND_NAVIGATION     3.5
# 3366  Color Call - Caller Screen, LED Flash      PERSONALIZATION     4.7
#
#      Reviews                Size    Installs  Type  Price Content Rating  \
# 8920     314                9.8M     50,000+  Free      0       Everyone
# 9064       8  Varies with device        500+  Paid  $3.99       Everyone
# 7822      26                8.5M        100+  Paid  $2.49       Everyone
# 1463   39189  Varies with device  1,000,000+  Free      0       Everyone
# 7033   41625                5.4M  1,000,000+  Free      0       Everyone
# 9074       0                 43M         10+  Free      0       Everyone
# 1210     454                 16M    100,000+  Free      0       Everyone
# 8204    4569                7.5M    500,000+  Free      0       Everyone
# 6870       8                 26M         10+  Free      0       Everyone
# 3366   29485                9.9M  1,000,000+  Free      0       Everyone
#
#                  Genres       Last Updated         Current Ver  \
# 8920  Books & Reference     March 17, 2016                2.10
# 9064            Medical   January 19, 2018  Varies with device
# 7822    Personalization   December 3, 2017               5.0.1
# 1463       House & Home      July 30, 2018  Varies with device
# 7033           Business  December 21, 2017               2.3.4
# 9074   Health & Fitness     August 6, 2018               4.4.1
# 1210       Food & Drink     March 28, 2018               2.0.0
# 8204  Maps & Navigation  December 22, 2017         2.1.10 (49)
# 6870  Maps & Navigation   January 17, 2018        1.2.20180117
# 3366    Personalization      July 20, 2018               1.0.4
#
#              Android Ver
# 8920        2.3.3 and up
# 9064  Varies with device
# 7822        4.0.3 and up
# 1463  Varies with device
# 7033          4.1 and up
# 9074          4.1 and up
# 1210        4.0.3 and up
# 8204          4.0 and up
# 6870          4.1 and up
# 3366          4.0 and up

# %% [markdown]
# ## 2. Remove unnecessary columns

# %%
apps = apps.drop(['Last Updated','Current Ver', 'Android Ver'], axis=1)
n=5
apps.sample(n)
# Out:
#                                    App            Category  Rating Reviews  \
# 1206                    SONIC Drive-In      FOOD_AND_DRINK     4.3   19314
# 7740          Gunship Modern Combat 3D                GAME     4.2    3247
# 1105      Bluebird by American Express             FINANCE     4.2   15703
# 1370  Zombies, Run! 5k Training (Free)  HEALTH_AND_FITNESS     4.0     267
# 2969              kicker football news              SPORTS     4.3   56270
#
#                     Size    Installs  Type Price Content Rating  \
# 1206                 43M  1,000,000+  Free     0       Everyone
# 7740                 26M    500,000+  Free     0           Teen
# 1105  Varies with device  1,000,000+  Free     0       Everyone
# 1370  Varies with device     50,000+  Free     0           Teen
# 2969                 15M  5,000,000+  Free     0       Everyone
#
#                 Genres
# 1206      Food & Drink
# 7740            Action
# 1105           Finance
# 1370  Health & Fitness
# 2969            Sports

# %% [markdown]
# ## 3. Error correction

# %%
# List of characters to remove
clean_chars = ['+', ',', '$','_']
# List of column names to clean
clean_cols = ['Installs', 'Price', 'Category']
for col in clean_cols:
    for char in clean_chars:
        # Replace the character with an empty string
        apps[col] = apps[col].apply(lambda x: x.replace(char, '  '))
apps = apps.fillna('')
        
apps.sample(10)
# Out:
#                                                     App          Category  \
# 6311                                 BJ Bridge Pro 2018              GAME
# 7397                      Pharmacie de Garde CI et Prix  HEALTHANDFITNESS
# 7210                          Grim Tales: The Wishes CE              GAME
# 8279  Driver Permit Test Prep DC DMV Driver's Licens...            FAMILY
# 5262                                          AJ-COMICS      FOODANDDRINK
# 7246                            Themes DAF CF 85 Trucks   PERSONALIZATION
# 2873                                       Photo Editor       PHOTOGRAPHY
# 3516               File Browser by Astro (File Manager)      PRODUCTIVITY
# 5097                                       EZ Ag Mobile           FINANCE
# 2809                                    Motorola Camera       PHOTOGRAPHY
#
#      Rating Reviews                Size  Installs  Type Price Content Rating  \
# 6311    4.4      17                4.8M       500  Paid  4.49       Everyone
# 7397    4.4    2599                6.9M    100000  Free     0     Mature 17+
# 7210    4.3    4923                 20M    100000  Free     0   Everyone 10+
# 8279    4.7      78                 11M      5000  Free     0       Everyone
# 5262              0                 27M         5  Free     0       Everyone
# 7246              2                 17M       100  Free     0           Teen
# 2873    4.3   42079                 17M   1000000  Free     0       Everyone
# 3516    4.3  609182                9.2M  50000000  Free     0       Everyone
# 5097    3.4      19                 24M      5000  Free     0       Everyone
# 2809    3.6  219745  Varies with device  50000000  Free     0       Everyone
#
#                 Genres
# 6311              Card
# 7397  Health & Fitness
# 7210         Adventure
# 8279         Education
# 5262      Food & Drink
# 7246   Personalization
# 2873       Photography
# 3516      Productivity
# 5097           Finance
# 2809       Photography

# %% [markdown]
# ## 4. Datatype uniformity/ standardization

# %%
import numpy as np
'''apps['Type'] = apps['Type'].str.replace('','').astype('float64')
apps["Installs"] = [float(str(i).replace("Free")) for i in apps["Installs"]]
print(apps.dtypes)'''

apps["Type"] = pd.to_numeric(apps["Type"], errors = 'coerce')
apps["Installs"] = pd.to_numeric(apps["Installs"], errors = 'coerce')
print(apps.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs          float64
# Type              float64
# Price              object
# Content Rating     object
# Genres             object
# dtype: object

# %%
apps
# Out:
#                                                      App           Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ARTANDDESIGN
# 1                                    Coloring book moana       ARTANDDESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ARTANDDESIGN
# 3                                  Sketch - Draw & Paint       ARTANDDESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ARTANDDESIGN
# ...                                                  ...                ...
# 10836                                   Sya9a Maroc - FR             FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings             FAMILY
# 10838                             Parkinson Exercices FR            MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKSANDREFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology          LIFESTYLE
#
#        Rating Reviews                Size  Installs  Type Price  \
# 0         4.1     159                 19M     10000  Free     0
# 1         3.9     967                 14M    500000  Free     0
# 2         4.7   87510                8.7M   5000000  Free     0
# 3         4.5  215644                 25M  50000000  Free     0
# 4         4.3     967                2.8M    100000  Free     0
# ...       ...     ...                 ...       ...   ...   ...
# 10836     4.5      38                 53M      5000  Free     0
# 10837     5.0       4                3.6M       100  Free     0
# 10838     NaN       3                9.5M      1000  Free     0
# 10839     4.5     114  Varies with device      1000  Free     0
# 10840     4.5  398307                 19M  10000000  Free     0
#
#       Content Rating                     Genres
# 0           Everyone               Art & Design
# 1           Everyone  Art & Design;Pretend Play
# 2           Everyone               Art & Design
# 3               Teen               Art & Design
# 4           Everyone    Art & Design;Creativity
# ...              ...                        ...
# 10836       Everyone                  Education
# 10837       Everyone                  Education
# 10838       Everyone                    Medical
# 10839     Mature 17+          Books & Reference
# 10840       Everyone                  Lifestyle
#
# [9660 rows x 10 columns]
